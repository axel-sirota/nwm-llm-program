# %% [markdown]
# # Homework: Python and Machine Learning Exercises

# %% [markdown]
# This notebook contains additional exercises to reinforce your understanding of Python and machine learning. The tasks are similar to what you've practiced before, but with some variations. Please complete the exercises by filling in the code where indicated.

# %% [markdown]
# ## Exercise 1: Python Functions and Lists

# %% [markdown]
# ### Task 1: Write a function that takes a list of strings and returns a new list with the lengths of each string.
# You need to iterate over the list using a loop and store the lengths in a new list.

# %% [markdown]
# ## Exercise 2: List Comprehensions and Conditionals

# %% [markdown]
# ### Task: Create a list comprehension that filters out even numbers from a given list and returns their squares.
# You will need to use an `if` condition within the list comprehension to filter out the even numbers.

# %% [markdown]
# ## Exercise 3: Decision Trees with California Housing Dataset

# %% [markdown]
# ### Task: Load the California Housing dataset, perform a train-test split, and implement a decision tree regressor to predict housing prices.
# You will use `DecisionTreeRegressor` to model the data and evaluate the model's performance.
#
# Remember to:
# - Split the data using `train_test_split`
# - Fit the `DecisionTreeRegressor` model
# - Predict and evaluate using metrics like MSE and R2 score.

# %% [markdown]
# ## Exercise 4: Support Vector Machines with Iris Dataset

# %% [markdown]
# ### Task: Load the Iris dataset, perform a train-test split, and implement a support vector classifier (SVC) to classify the species of iris flowers.
# You will use `SVC` to predict the species of iris based on the features. Remember to split the data first.
#
# Steps:
# - Load the Iris dataset
# - Split the data into training and testing sets
# - Train the SVC model
# - Predict and evaluate the model's accuracy

# %% [markdown]
# ## Exercise 5: Clustering with DBSCAN and PCA

# %% [markdown]
# ### Task: Use PCA to reduce the dimensions of the Iris dataset and then perform DBSCAN clustering.
# First, apply PCA to reduce the feature dimensions, and then use DBSCAN to cluster the data.
#
# Steps:
# - Apply PCA to reduce to 2 components
# - Fit the DBSCAN clustering algorithm
# - Predict and analyze the clusters
